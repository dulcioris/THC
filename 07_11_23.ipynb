# %% [markdown]
# <a href="https://colab.research.google.com/github/dulcioris/THC/blob/main/07_11_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
link='https://github.com/seismomat/HerramientasComputacionales/blob/43a0d2c53fd5dbc11949e040f19b309ab588bd39/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code='?raw=true'
url=link+code
df=pd.read_csv(url,sep=',',index_col=1)

# %%
df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# ...

# %%
df.shape
#(elementos,columnas)
# Out:
# (2484, 3)

# %%
df.info()
#detalles o contenido del archivo y te dice cuanto pesa
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 2014-08-29 to 2016-03-23
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  2484 non-null   object
#  1   No. of confirmed cases   2484 non-null   float64
#  2   No. of confirmed deaths  1648 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 142.2+ KB

# %%
df.head()
#los primeros 5 de la lista
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29        Guinea                   482.0                    287.0
# 2014-08-29       Nigeria                    15.0                      6.0
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-08-29       Liberia                   322.0                    225.0
# 2014-09-05        Guinea                   604.0                    362.0

# %%
df.tail()
#los ultimos 5, cola
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0

# %%
df.isnull()
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-09-05    False                   False                    False
# ...             ...                     ...                      ...
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
#
# [2484 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# dtype: int64

# %%
df['Country']
# Out:
# Date
# 2014-08-29                      Guinea
# 2014-08-29                     Nigeria
# 2014-08-29                Sierra Leone
# 2014-08-29                     Liberia
# 2014-09-05                      Guinea
#                         ...
# 2016-03-23                     Liberia
# 2016-03-23                       Italy
# 2016-03-23                     Liberia
# 2016-03-23                     Nigeria
# 2016-03-23    United States of America
# Name: Country, Length: 2484, dtype: object

# %%
df['Country'].isin(['Mexico'])
# Out:
# Date
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29    False
# 2014-09-05    False
#               ...
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# Name: Country, Length: 2484, dtype: bool

# %%
df['Country'].isin(['Mexico']).sum()
# Out:
# 0

# %%
df['Country'].isin(['Nigeria']).sum()
# Out:
# 255

# %%
SL=df[df['Country']=='Sierra Leone']

# %%
df['Country']=='Sierra Leone'
# Out:
# Date
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29     True
# 2014-08-29    False
# 2014-09-05    False
#               ...
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# Name: Country, Length: 2484, dtype: bool

# %%
SL=SL.drop('Country',axis=1)
#no puede ser axis=0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-9da22eec27bd> in <cell line: 1>()
# ----> 1 SL=SL.drop('Country',axis=1)
#       2 #no puede ser axis=0
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29                   935.0                    380.0
# 2014-09-05                  1146.0                    443.0
# 2014-09-08                  1234.0                    461.0
# 2014-09-12                  1287.0                    478.0
# 2014-09-16                  1464.0                    514.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['No. of confirmed cases'].plot(kind='hist', bins=20, title='No. of confirmed cases')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['No. of confirmed deaths'].plot(kind='hist', bins=20, title='No. of confirmed deaths')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
# ...

# %%
SL[15:20]
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-10-22                  3223.0                    986.0
# 2014-10-25                  3389.0                   1008.0
# 2014-10-29                  3700.0                      NaN
# 2014-10-31                  3778.0                      NaN
# 2014-11-05                  4057.0                    893.0

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    2
# dtype: int64

# %%
SL.shape
# Out:
# (259, 2)

# %%
SL.fillna(0.0,inplace=True)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    0
# dtype: int64

# %%
SL['No. of confirmed deaths'].mean()
# Out:
# 3081.019305019305

# %%
SL['No. of confirmed cases'].mean()
# Out:
# 7883.671814671815

# %%
Dates=SL.index[0:-1:10]
NCC=SL['No. of confirmed cases'][0:-1:10]
NCD=SL['No. of confirmed deaths'][0:-1:10]

# %%
plt.plot(Dates,NCC,'o--r',ms=4,label='Infectados')
plt.plot(Dates,NCD,'o-k',ms=-4,label='Decesos')
plt.grid()
plt.title('Avance del Ébola en Sierra Leona')
plt.ylabel('Casos Confirmados')
plt.xlabel('Periodo de Tiempo')
plt.xticks(rotation=90,fontsize=8)
plt.legend()
plt.show()

# %%
PIvsD=100*SL['No. of confirmed deaths']/SL['No. of confirmed cases']
SL['PIvsD']=PIvsD

# %%
SL
# Out:
#             No. of confirmed cases  No. of confirmed deaths       PIvsD
# Date
# 2014-08-29                   935.0                    380.0  246.052632
# 2014-09-05                  1146.0                    443.0  258.690745
# 2014-09-08                  1234.0                    461.0  267.678959
# 2014-09-12                  1287.0                    478.0  269.246862
# 2014-09-16                  1464.0                    514.0  284.824903
# ...                            ...                      ...         ...
# 2015-12-17                  8704.0                   3589.0  242.518807
# 2015-12-22                  8704.0                   3589.0  242.518807
# 2015-12-23                  8704.0                   3589.0  242.518807
# 2015-12-29                  8704.0                   3589.0  242.518807
# 2016-03-23                  8704.0                   3589.0  242.518807
#
# [259 rows x 3 columns]

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD  \
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290
#
#             recuperados
# Date
# 2014-08-29 -1365.592105
# 2014-09-05 -1818.595937
# 2014-09-08 -2069.158351
# 2014-09-12 -2178.207113
# 2014-09-16 -2705.836576

# %%
recuperados=((100-PIvsD)/100)*SL['No. of confirmed cases']
SL['recuperados']=recuperados

# %%
SL.head
# Out:
# <bound method NDFrame.head of             No. of confirmed cases  No. of confirmed deaths      PIvsD  \
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290
# ...                            ...                      ...        ...
# 2015-12-17                  8704.0                   3589.0  41.233915
# 2015-12-22                  8704.0                   3589.0  41.233915
# 2015-12-23                  8704.0                   3589.0  41.233915
# 2015-12-29                  8704.0                   3589.0  41.233915
# 2016-03-23                  8704.0                   3589.0  41.233915
#
#             recuperados
# Date
# 2014-08-29        555.0
# ...
